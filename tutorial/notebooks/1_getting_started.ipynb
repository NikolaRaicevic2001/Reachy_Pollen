# %% [markdown]
# # Getting started with Reachy 2

# %% [markdown]
# In this first tutorial, we will familiarize ourselves with Reachy. We will cover how to connect to the robot and obtain basic information.

# %% [markdown]
# ## Connect to Reachy

# %% [markdown]
# First, establish a connection to your robot:

# %%
from reachy2_sdk import ReachySDK

reachy = ReachySDK(host='192.168.10.172')
# Out:
# Local API version (1.0.21) is different from the robot's API version (1.0.19).
# Some features may not work properly.
# Please update the reachy2_core image on the robot to ensure compatibility, or downgrade your local reachy2_sdk package.
# This Reachy is in REAL mode :
# ⚠️  Be careful, you're controlling the PHYSICAL Reachy.

# %% [markdown]
# You can check the connection status at any time with:

# %%
reachy.is_connected()
# Out:
# True

# %% [markdown]
# Reachy is now ready for use. By default, all motors are turned off. In the next tutorial, we will learn how to move Reachy. The overall status of Reachy's motors can be checked as follows:

# %%
reachy.is_on() # will return False because the motors are off by default
# Out:
# False

# %% [markdown]
# Let's retrieve information about the robot, including mode, serial number, hardware / software versions, and battery level:

# %%
reachy.info
# Out:
# <ReachyInfo mode="REAL"
#  robot_serial_number="r2-0008"
#  hardware_version=""
#  core_software_version="1.7.5.9"
#  robot_api_version="1.0.19"
#  battery_voltage=25.9 >

# %% [markdown]
# You can also access these informations independently, for example:

# %%
reachy.info.battery_voltage
# Out:
# 26.0
# This Reachy is in REAL mode :
# ⚠️  Be careful, you're controlling the PHYSICAL Reachy.

# %% [markdown]
# ## Body parts

# %% [markdown]
# Let's take a look at Reachy's body. Reachy's arm has 7 degrees of freedom and one joint for the gripper.
#
# The **arm** is divided into the following elements:
# - **shoulder**, consisting of 2 joints (pitch and roll)
# - **elbow**, consisting of 2 joints (yaw and pitch)
# - **wrist**, consisting of 3 joints (roll, pitch, and yaw)
# - **gripper**, consisting by default of 1 joint accessed directly at the gripper level
#
# We refer to the shoulder, elbow, and wrist as **actuators**. A joint is essentially an axis along which the actuator can rotate.
# For some actions, such as changing the compliancy, this is the lowest level of control you will have.
# The default parallel gripper is a specific actuator that has only one joint, so everything is accessed at its level.
#
# The head consists of three actuators: the **neck**, with 3 degrees of freedom (joints), and **l_antenna** and **r_antenna**, with a single joint for each of them.
#
# The following command lists all available joints:

# %%
reachy.joints
# Out:
# {'r_arm.shoulder.pitch': <OrbitaJoint axis_type="pitch" present_position=3.47 goal_position=3.47 >,
# 'r_arm.shoulder.roll': <OrbitaJoint axis_type="roll" present_position=18.58 goal_position=18.58 >,
# 'r_arm.elbow.yaw': <OrbitaJoint axis_type="yaw" present_position=-59.83 goal_position=-59.83 >,
# 'r_arm.elbow.pitch': <OrbitaJoint axis_type="pitch" present_position=-16.65 goal_position=-16.65 >,
# 'r_arm.wrist.roll': <OrbitaJoint axis_type="roll" present_position=10.1 goal_position=10.1 >,
# 'r_arm.wrist.pitch': <OrbitaJoint axis_type="pitch" present_position=1.61 goal_position=1.61 >,
# 'r_arm.wrist.yaw': <OrbitaJoint axis_type="yaw" present_position=53.55 goal_position=53.55 >,
# 'r_arm.gripper': <GripperJoint on=True present_position=130.08 goal_position=130.0 >,
# 'l_arm.shoulder.pitch': <OrbitaJoint axis_type="pitch" present_position=-0.45 goal_position=-0.45 >,
# 'l_arm.shoulder.roll': <OrbitaJoint axis_type="roll" present_position=-14.29 goal_position=-14.29 >,
# 'l_arm.elbow.yaw': <OrbitaJoint axis_type="yaw" present_position=9.25 goal_position=9.25 >,
# 'l_arm.elbow.pitch': <OrbitaJoint axis_type="pitch" present_position=-0.29 goal_position=-0.29 >,
# 'l_arm.wrist.roll': <OrbitaJoint axis_type="roll" present_position=-7.0 goal_position=-7.0 >,
# 'l_arm.wrist.pitch': <OrbitaJoint axis_type="pitch" present_position=-4.72 goal_position=-4.72 >,
# 'l_arm.wrist.yaw': <OrbitaJoint axis_type="yaw" present_position=-0.0 goal_position=-0.0 >,
# 'l_arm.gripper': <GripperJoint on=True present_position=129.99 goal_position=130.0 >,
# 'head.neck.roll': <OrbitaJoint axis_type="roll" present_position=-1.95 goal_position=-1.95 >,
# 'head.neck.pitch': <OrbitaJoint axis_type="pitch" present_position=4.31 goal_position=4.31 >,
# 'head.neck.yaw': <OrbitaJoint axis_type="yaw" present_position=-3.37 goal_position=-3.37 >,
# 'head.l_antenna': <DynamixelMotor on=True present_position=-0.26 goal_position=-0.26 >,
# 'head.r_antenna': <DynamixelMotor on=True present_position=-0.62 goal_position=-0.62 >}

# %% [markdown]
# The current and goal positions are also listed (i.e., the present and target angles of the joints).
# Each body part can be explored individually:

# %%
reachy.r_arm.joints
#reachy.l_arm.joints
#reachy.head.joints
# Out:
# {'shoulder.pitch': <OrbitaJoint axis_type="pitch" present_position=3.47 goal_position=3.47 >,
# 'shoulder.roll': <OrbitaJoint axis_type="roll" present_position=18.58 goal_position=18.58 >,
# 'elbow.yaw': <OrbitaJoint axis_type="yaw" present_position=-59.83 goal_position=-59.83 >,
# 'elbow.pitch': <OrbitaJoint axis_type="pitch" present_position=-16.65 goal_position=-16.65 >,
# 'wrist.roll': <OrbitaJoint axis_type="roll" present_position=10.1 goal_position=10.1 >,
# 'wrist.pitch': <OrbitaJoint axis_type="pitch" present_position=1.61 goal_position=1.61 >,
# 'wrist.yaw': <OrbitaJoint axis_type="yaw" present_position=53.55 goal_position=53.55 >,
# 'gripper': <GripperJoint on=True present_position=130.08 goal_position=130.0 >}

# %% [markdown]
# ## Mobile Base

# %% [markdown]
# The mobile base can be accessed in the same way as the body parts:
# > Be aware that there is no mobile base in the fake mode configuration.

# %%
reachy.mobile_base
# Out:
# <MobileBase on=True
#  lidar_safety_enabled=True
#  battery_voltage=25.8>

# %% [markdown]
# ## Disconnect

# %% [markdown]
# No action is required; simply close your terminal or notebook!
#
# If you need to switch between robots, you can disconnect from one and then connect to another:

# %%
reachy.disconnect()

reachy = ReachySDK(host='192.168.10.172') # connect to a new robot with its IP address
# Out:
# Reachy gRPC stream is shutting down.
# Local API version (1.0.21) is different from the robot's API version (1.0.19).
# Some features may not work properly.
# Please update the reachy2_core image on the robot to ensure compatibility, or downgrade your local reachy2_sdk package.
# This Reachy is in REAL mode :
# ⚠️  Be careful, you're controlling the PHYSICAL Reachy.
# This Reachy is in REAL mode :
# ⚠️  Be careful, you're controlling the PHYSICAL Reachy.
#
# Exception in thread Thread-44 (_start_sync_in_bg):
# Traceback (most recent call last):
#   File "/home/nikolaraicevic/Workspace/Internal/Reachy_Pollen/reachy2/lib/python3.10/site-packages/reachy2_sdk/reachy_sdk.py", line 525, in _get_stream_update_loop
# Exception in thread Thread-45 (_audit):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     for state_update in reachy_stub.StreamReachyState(stream_req):
#   File "/home/nikolaraicevic/Workspace/Internal/Reachy_Pollen/reachy2/lib/python3.10/site-packages/grpc/_channel.py", line 543, in __next__
#     self._target(*self._args, **self._kwargs)
#   File "/home/nikolaraicevic/Workspace/Internal/Reachy_Pollen/reachy2/lib/python3.10/site-packages/reachy2_sdk/reachy_sdk.py", line 554, in _audit
#     return self._next()
#   File "/home/nikolaraicevic/Workspace/Internal/Reachy_Pollen/reachy2/lib/python3.10/site-packages/grpc/_channel.py", line 969, in _next
#     audit_status = self._stub.Audit(self._robot.id)
#   File "/home/nikolaraicevic/Workspace/Internal/Reachy_Pollen/reachy2/lib/python3.10/site-packages/grpc/_channel.py", line 1181, in __call__
#     raise self
# grpc._channel._MultiThreadedRendezvous: <_MultiThreadedRendezvous of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "recvmsg:Connection reset by peer"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:192.168.10.172:50051 {grpc_message:"recvmsg:Connection reset by peer", grpc_status:14}"
# >
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     return _end_unary_response_blocking(state, call, False, None)
#   File "/home/nikolaraicevic/Workspace/Internal/Reachy_Pollen/reachy2/lib/python3.10/site-packages/grpc/_channel.py", line 1006, in _end_unary_response_blocking
#     self._target(*self._args, **self._kwargs)
#   File "/home/nikolaraicevic/Workspace/Internal/Reachy_Pollen/reachy2/lib/python3.10/site-packages/reachy2_sdk/reachy_sdk.py", line 514, in _start_sync_in_bg
#     raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
# grpc._channel._InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "recvmsg:Connection reset by peer"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_status:14, grpc_message:"recvmsg:Connection reset by peer"}"
# >
#     self._get_stream_update_loop(reachy_stub, freq=100)
#   File "/home/nikolaraicevic/Workspace/Internal/Reachy_Pollen/reachy2/lib/python3.10/site-packages/reachy2_sdk/reachy_sdk.py", line 544, in _get_stream_update_loop
#     raise ConnectionError(f"Connection with Reachy ip:{self._host} lost, check the SDK server status.")
# ConnectionError: Connection with Reachy ip:192.168.10.172 lost, check the SDK server status.
